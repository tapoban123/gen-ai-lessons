# %% [markdown]
# # Resources:
# 1. [Get your OpenAI API key](https://platform.openai.com/docs/quickstart?api-mode=responses)
# 3. [Check number of tokens in a text](https://platform.openai.com/tokenizer)
# 4. [Test OpenAI api on OpenAI Playground](https://platform.openai.com/playground/prompts?models=gpt-4o)

# %%
# %pip install openai
# %pip install pandas

# %%
from openai import OpenAI

# %% [markdown]
# ## Setting up OpenAI
#
# 1. Install openai package.
# 2. Login into [OpenAI](https://platform.openai.com/docs/quickstart?api-mode=responses)
# 3. Generate API key.

# %%
api_key = "api_key"

# %%
client = OpenAI(api_key=api_key)

# %%
all_models=client.models.list()

# %%
import pandas as pd

# %%
pd.DataFrame(all_models, columns=('id', 'created_at', 'object', 'owned by'))
# Out:
#                                              id             created_at  \
# 0                                (id, dall-e-3)  (created, 1698785189)
# 1                                (id, dall-e-2)  (created, 1698798177)
# 2         (id, gpt-4o-audio-preview-2024-10-01)  (created, 1727389042)
# 3                       (id, gpt-4o-transcribe)  (created, 1742068463)
# 4                  (id, gpt-4o-mini-transcribe)  (created, 1742068596)
# 5                             (id, babbage-002)  (created, 1692634615)
# 6                         (id, gpt-4o-mini-tts)  (created, 1742403959)
# 7                           (id, tts-1-hd-1106)  (created, 1699053533)
# 8                  (id, text-embedding-3-large)  (created, 1705953180)
# 9                  (id, text-embedding-ada-002)  (created, 1671217299)
# 10                               (id, tts-1-hd)  (created, 1699046015)
# 11              (id, gpt-4o-mini-audio-preview)  (created, 1734387424)
# ...

# %% [markdown]
# ### Test the OpenAI api on [OpenAI Playground](https://platform.openai.com/playground/prompts?models=gpt-4o).

# %%
from openai import OpenAI
# client = OpenAI()

response = client.responses.create(
  model="gpt-4o",
  input=[],
  text={
    "format": {
      "type": "text"
    }
  },
  reasoning={},
  tools=[],
  temperature=1,
  max_output_tokens=2048,
  top_p=1,
  store=True
)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[19], line 4
#       1 from openai import OpenAI
#       2 # client = OpenAI()
# ----> 4 response = client.responses.create(
#       5   model="gpt-4o",
#       6   input=[],
#       7   text={
#       8     "format": {
#       9       "type": "text"
#      10     }
#      11   },
#      12   reasoning={},
#      13   tools=[],
#      14   temperature=1,
#      15   max_output_tokens=2048,
#      16   top_p=1,
#      17   store=True
#      18 )
#
# File /opt/anaconda3/envs/python3_8/lib/python3.8/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# # OpenAI with Langchain

# %%
# %pip install -U langchain-openai

# %%
from langchain_openai import OpenAI

# %%
client = OpenAI(api_key="api_key")
print(client.invoke(prompt).strip())
