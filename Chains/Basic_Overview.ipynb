# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate
import os

# %%
GEMINI_API = os.environ.get("GEMINI_API_KEY")
GEMINI_MODEL = "gemini-2.0-flash"

# %%
llm = ChatGoogleGenerativeAI(
    api_key=GEMINI_API,
    model=GEMINI_MODEL,
    temperature=0,
    max_retries=2,
)

# %% [markdown]
# ## Simple Chains

# %%
prompt = PromptTemplate.from_template(
    "What is a good name for a company that manufactures {product}?"
)

# Connecting llm and prompt.
chain = prompt | llm | StrOutputParser()

ai_answer = chain.invoke("Toys")

print(ai_answer)
# Out:
# Okay, let's brainstorm some toy company names! I'll try to give you a variety, playing with different angles:
#
# **1. Classic & Playful:**
#
# *   Playful Pals Toys
# *   Wonderland Toys
# *   Joyful Creations
# *   Happy Hearts Toys
# *   Giggle Gear
# *   Toybox Treasures
# *   The Toy Emporium
# *   Playtime Paradise
# *   Imagination Station Toys
# *   Fun Factory Toys
#
# **2. Modern & Catchy:**
#
# *   ToyVerse
# *   PlayLab
# *   KidSpark
# *   ToyZenith
# *   MiniMakers
# *   Buildify
# *   Create & Play Co.
# *   The Toy Foundry
# *   Pixel Play
# *   Nova Toys
#
# **3. Educational & Developmental:**
#
# *   Smart Start Toys
# *   Little Learners
# *   Brainy Blocks
# *   Creative Kids Co.
# *   Discovery Toys
# *   The Learning Tree Toys
# *   Future Builders
# *   ThinkPlay
# *   Explore & Grow Toys
# *   Mindful Play
#
# **4. Unique & Quirky:**
#
# *   Whimsical Wonders
# *   The Curious Toy
# *   Oddball Toys
# *   The Giggle Garden
# *   Silly Sprockets
# *   The Imaginary Menagerie
# *   Pocketful of Posies Toys
# *   The Nifty Toy Co.
# *   Doodlebug Toys
# *   The Playful Paradox
#
# **5. Names Emphasizing Quality & Craftsmanship:**
#
# *   Heirloom Toys
# *   Artisan Toys
# *   The Crafted Toy
# *   Timeless Toys
# *   Durable Play
# *   Legacy Toys
# *   The Quality Toy Co.
# *   Finely Crafted Toys
# *   The Toy Smithy
# *   Evergreen Toys
#
# **6. Names Based on a Specific Type of Toy (If Applicable):**
#
# *   (If you make building blocks) Block Builders Co.
# *   (If you make dolls) Dollhouse Dreams
# *   (If you make plush toys) Cuddle Buddies
# *   (If you make outdoor toys) Adventure Awaits Toys
# *   (If you make board games) Game Night Central
#
# **Tips for Choosing the Best Name:**
#
# *   **Target Audience:** Who are you trying to reach? (Parents, kids, educators?)
# *   **Brand Identity:** What kind of image do you want to project? (Fun, educational, high-quality?)
# *   **Memorability:** Is the name easy to remember and pronounce?
# *   **Availability:** Check if the name is available as a website domain and social media handle.
# *   **Trademark:** Make sure the name isn't already trademarked by another company.
# *   **Keep it Short and Sweet:** Shorter names are generally easier to remember.
# *   **Get Feedback:** Ask friends, family, or potential customers for their opinions.
#
# To help me narrow down the best suggestions, tell me:
#
# *   **What type of toys will you be manufacturing?** (e.g., wooden toys, educational toys, plush toys, etc.)
# *   **What is your target audience?** (e.g., babies, toddlers, older children, collectors)
# *   **What is the overall feel or aesthetic of your brand?** (e.g., modern, classic, whimsical, eco-friendly)
#
# Good luck!

# %% [markdown]
# ## Sequential Chains

# %%
prompt = PromptTemplate.from_template(
    "I want to start a company that manufactures {product}. Please tell me a good name for my company."
)

prompt2 = PromptTemplate.from_template(
    "Tell me the strategy of building a successful business on manufacturing of {product}."
)

chain1 = prompt | llm | StrOutputParser()
chain2 = prompt2 | llm | StrOutputParser()

final_chain = chain1 | chain2
ai_answer = final_chain.invoke({"product": "Electronic Gadgets"})
print(ai_answer)
# Out:
# Okay, great! Now that we have a solid list of potential names, let's move on to the core of your question: **the strategy of building a successful business on manufacturing electronic gadgets.**
#
# Here's a comprehensive strategy, broken down into key areas:
#
# **I. Market Research & Product Strategy:**
#
# *   **1. Identify a Niche (Crucial):** Don't try to compete with giants like Apple or Samsung head-on.  Find a specific niche market with unmet needs or underserved customers.  Examples:
#     *   **Eco-Friendly Gadgets:**  Focus on sustainable materials, energy efficiency, and ethical manufacturing.
#     *   **Assistive Technology:**  Develop gadgets for people with disabilities.
#     *   **Industrial IoT Devices:**  Create sensors and devices for specific industries (agriculture, manufacturing, logistics).
#     *   **Niche Gaming Accessories:**  Develop specialized controllers, VR peripherals, or streaming equipment.
#     *   **Smart Home Solutions for Specific Needs:**  Focus on security, energy management, or elderly care.
# *   **2. Deep Dive into Market Research:**
#     *   **Target Audience:**  Who are your ideal customers?  What are their needs, pain points, and buying habits?
#     *   **Competitive Analysis:**  Identify your competitors, analyze their strengths and weaknesses, and determine how you can differentiate yourself.
#     *   **Market Trends:**  Stay up-to-date on the latest technology trends and consumer preferences.
#     *   **Regulatory Landscape:**  Understand the relevant regulations and certifications for your products (e.g., FCC, CE, RoHS).
# *   **3. Product Development & Design:**
#     *   **Focus on Innovation:**  Develop unique and innovative products that solve real problems.
#     *   **User-Centric Design:**  Prioritize user experience (UX) and create products that are easy to use and enjoyable.
#     *   **Prototyping & Testing:**  Create prototypes and test them thoroughly to identify and fix any issues.
#     *   **Intellectual Property Protection:**  Consider patents, trademarks, and copyrights to protect your inventions and brand.
# *   **4. Minimum Viable Product (MVP):** Start with a basic version of your product to test the market and gather feedback before investing in full-scale production.
#
# **II. Manufacturing & Supply Chain:**
#
# *   **1. Manufacturing Options:**
#     *   **In-House Manufacturing:**  Requires significant investment in equipment, personnel, and facilities.  Offers greater control over quality and production processes.  Best for highly specialized or low-volume products.
#     *   **Outsourcing (Contract Manufacturing):**  Partner with a contract manufacturer (CM) to handle production.  Reduces capital investment and allows you to focus on other areas of the business.  Requires careful selection and management of the CM.
#     *   **Hybrid Approach:**  Combine in-house manufacturing for critical components or final assembly with outsourcing for other parts.
# *   **2. Selecting a Contract Manufacturer (If Outsourcing):**
#     *   **Experience:**  Choose a CM with experience in manufacturing similar products.
#     *   **Quality Control:**  Ensure the CM has robust quality control processes in place.
#     *   **Capacity:**  Verify the CM has the capacity to meet your production needs.
#     *   **Cost:**  Compare quotes from multiple CMs to get the best price.
#     *   **Communication:**  Establish clear communication channels with the CM.
#     *   **Location:**  Consider the location of the CM in terms of shipping costs, lead times, and cultural differences.
# *   **3. Supply Chain Management:**
#     *   **Sourcing Components:**  Identify reliable suppliers for all the components needed for your products.
#     *   **Inventory Management:**  Implement an efficient inventory management system to minimize waste and avoid stockouts.
#     *   **Logistics & Shipping:**  Establish a reliable logistics and shipping network to deliver products to customers on time.
#     *   **Risk Management:**  Identify potential risks in the supply chain (e.g., natural disasters, political instability) and develop contingency plans.
# *   **4. Quality Assurance:**
#     *   **Implement a Quality Management System (QMS):**  Such as ISO 9001, to ensure consistent quality throughout the manufacturing process.
#     *   **Regular Inspections:**  Conduct regular inspections of the manufacturing facility and products.
#     *   **Testing & Certification:**  Test products to ensure they meet relevant standards and obtain necessary certifications.
#
# **III. Sales & Marketing:**
#
# *   **1. Define Your Target Market:**  Reiterate this from the market research.  Knowing *who* you're selling to is paramount.
# *   **2. Develop a Brand Identity:**  Create a strong brand identity that reflects your company's values and resonates with your target audience.  This includes your logo, colors, fonts, and overall messaging.
# *   **3. Choose Your Sales Channels:**
#     *   **Direct Sales (Online):**  Create an e-commerce website to sell directly to customers.
#     *   **Direct Sales (Offline):**  Attend trade shows and industry events to showcase your products.
#     *   **Retail Partnerships:**  Partner with retailers to sell your products in their stores.
#     *   **Distributors:**  Work with distributors to reach a wider audience.
#     *   **Online Marketplaces:**  Sell your products on online marketplaces like Amazon, eBay, and Etsy.
# *   **4. Marketing Strategies:**
#     *   **Content Marketing:**  Create valuable content (blog posts, articles, videos) to attract and engage your target audience.
#     *   **Social Media Marketing:**  Use social media platforms to build brand awareness and connect with customers.
#     *   **Search Engine Optimization (SEO):**  Optimize your website and content to rank higher in search engine results.
#     *   **Paid Advertising:**  Use paid advertising (e.g., Google Ads, social media ads) to reach a wider audience.
#     *   **Public Relations (PR):**  Get your products featured in media outlets and industry publications.
#     *   **Email Marketing:**  Build an email list and send out newsletters and promotional offers.
#     *   **Influencer Marketing:**  Partner with influencers to promote your products to their followers.
# *   **5. Customer Service:**
#     *   **Provide excellent customer service:**  Respond promptly to inquiries and resolve issues quickly.
#     *   **Build relationships with customers:**  Encourage feedback and build a community around your brand.
#
# **IV. Operations & Management:**
#
# *   **1. Business Plan:**  Develop a comprehensive business plan that outlines your goals, strategies, and financial projections.
# *   **2. Funding:**  Secure funding through investors, loans, or grants.
# *   **3. Legal & Regulatory Compliance:**  Ensure your business complies with all relevant laws and regulations.
# *   **4. Team Building:**  Assemble a skilled and motivated team.
# *   **5. Financial Management:**  Track your finances carefully and manage your cash flow effectively.
# *   **6. Continuous Improvement:**  Continuously monitor your performance and identify areas for improvement.
#
# **V. Key Success Factors:**
#
# *   **Innovation:**  Develop unique and innovative products that solve real problems.
# *   **Quality:**  Maintain high quality standards throughout the manufacturing process.
# *   **Customer Focus:**  Prioritize customer satisfaction and build strong relationships.
# *   **Efficiency:**  Optimize your operations to minimize costs and maximize efficiency.
# *   **Adaptability:**  Be prepared to adapt to changing market conditions and technological advancements.
# *   **Strong Leadership:**  Provide strong leadership and direction to your team.
# *   **Persistence:**  Be persistent and resilient in the face of challenges.
#
# **Specific Considerations for Electronic Gadget Manufacturing:**
#
# *   **Component Sourcing:**  The global chip shortage is still a factor.  Establish strong relationships with multiple suppliers and consider alternative components.
# *   **Rapid Prototyping:**  Invest in rapid prototyping tools (3D printers, laser cutters) to quickly iterate on designs.
# *   **Software Integration:**  Many gadgets require software integration.  Ensure you have the necessary software development expertise.
# *   **Data Security:**  If your gadgets collect or transmit data, prioritize data security and privacy.
# *   **Obsolescence:**  Electronic gadgets can become obsolete quickly.  Plan for product lifecycle management and consider offering upgrades or replacements.
#
# **In summary, building a successful electronic gadget manufacturing business requires a combination of market research, product innovation, efficient manufacturing, effective marketing, and strong management. By focusing on a niche market, developing high-quality products, and providing excellent customer service, you can increase your chances of success.**
#
# Remember to start small, test your assumptions, and be prepared to adapt as you learn and grow. Good luck! Let me know if you have any more specific questions.
